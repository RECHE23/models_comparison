# %% [markdown]
# ### Comparison of the effect of using different depths of layers (Tanh) - Sequential

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('OXrFkht81gw', width=960, height=540)

# %% [markdown]
# ### Comparison of the effect of using different depths of layers (Tanh) - Batches of 32

# %%
YouTubeVideo('L61HBrI1Y6g', width=960, height=540)

# %% [markdown]
# ### Imports & setup

# %%
# Refer to the parent path:
import sys
sys.path.append('../')

# Import the helper scripts:
from utils import *

# Name of the experiment:
name="amount_of_layers_tanh"

# %matplotlib inline

# %% [markdown]
# ### Generate a two moons dataset

# %%
X_moons, y_moons = sklearn.datasets.make_moons(150, noise=0.25, random_state=0)
y_moons = np.where(y_moons==0, -1., y_moons)
plt.scatter(X_moons[:,0], X_moons[:,1], s=40, c=y_moons)

# %% [markdown]
# ### Generate a two blobs dataset

# %%
X_blobs, y_blobs = sklearn.datasets.make_blobs(n_samples=150, centers=2, n_features=2, random_state=0)
y_blobs = np.where(y_blobs==0, -1., y_blobs)
plt.scatter(X_blobs[:,0], X_blobs[:,1], s=40, c=y_blobs)

# %% [markdown]
# ### Generate a concentric circles dataset

# %%
X_circles, y_circles = sklearn.datasets.make_circles(n_samples=150, noise=0.09, random_state=0)
y_circles = np.where(y_circles==0, -1., y_circles)
plt.scatter(X_circles[:,0], X_circles[:,1], s=40, c=y_circles)

# %% [markdown]
# ### Convert SKLearn datasets into PyTorch datasets

# %%
moons_dataset = convert_to_pytorch_dataset(X_moons, y_moons)
blobs_dataset = convert_to_pytorch_dataset(X_blobs, y_blobs)
circles_dataset = convert_to_pytorch_dataset(X_circles, y_circles)

datasets = [moons_dataset, blobs_dataset, circles_dataset]

# %% [markdown]
# ### Create classifier models

# %%
# A 3 layers hyperbolic tangent based neural network:
class TanhNet_3layers(nn.Module):
    def __init__(self, input_size):
        super(TanhNet_3layers, self).__init__()
        self.layers = nn.Sequential(nn.Flatten(),
                                    nn.Linear(input_size, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 1))

    def forward(self, x):
        return torch.erf(self.layers(x))

# A 4 layers hyperbolic tangent based neural network:
class TanhNet_4layers(nn.Module):
    def __init__(self, input_size):
        super(TanhNet_4layers, self).__init__()
        self.layers = nn.Sequential(nn.Flatten(),
                                    nn.Linear(input_size, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 1))

    def forward(self, x):
        return torch.erf(self.layers(x))

# A 5 layers hyperbolic tangent based neural network:
class TanhNet_5layers(nn.Module):
    def __init__(self, input_size):
        super(TanhNet_5layers, self).__init__()
        self.layers = nn.Sequential(nn.Flatten(),
                                    nn.Linear(input_size, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 1))

    def forward(self, x):
        return torch.erf(self.layers(x))
    
# A 6 layers hyperbolic tangent based neural network:
class TanhNet_6layers(nn.Module):
    def __init__(self, input_size):
        super(TanhNet_6layers, self).__init__()
        self.layers = nn.Sequential(nn.Flatten(),
                                    nn.Linear(input_size, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 1))

    def forward(self, x):
        return torch.erf(self.layers(x))

# A 7 layers hyperbolic tangent based neural network:
class TanhNet_7layers(nn.Module):
    def __init__(self, input_size):
        super(TanhNet_7layers, self).__init__()
        self.layers = nn.Sequential(nn.Flatten(),
                                    nn.Linear(input_size, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 32),
                                    nn.Tanh(),
                                    nn.Linear(32, 1))

    def forward(self, x):
        return torch.erf(self.layers(x))

# Selected models are initialized for every dataset:
models = [{
    'Tanh 3 layers': TanhNet_3layers(2),
    'Tanh 4 layers': TanhNet_4layers(2),
    'Tanh 5 layers': TanhNet_5layers(2),
    'Tanh 6 layers': TanhNet_6layers(2),
    'Tanh 7 layers': TanhNet_7layers(2)
          } for _ in datasets]

# %% [markdown]
# ### Select the learning parameters

# %%
lr = 0.01    # Learning rate
mm = 0.9     # Momentum
wd = 0.001   # Weight decay

optimizers = [dict((k, torch.optim.SGD(model.parameters(), lr=lr, momentum=mm, weight_decay=wd))
                   for k, model in models[i].items()) for i in range(len(datasets))]

# Loss function:
criterion = nn.MSELoss()

# Number of epochs:
epochs = 300

# Sampling method:
batch_size=32
shuffle=True

# %% [markdown]
# ### Generates the animated plot

# %%
generate_animated_plot(epochs=epochs, 
                       datasets=datasets, 
                       models=models, 
                       optimizers=optimizers, 
                       criterion=criterion, 
                       filename=name, 
                       batch_size=batch_size, 
                       shuffle=shuffle)

# %% [markdown]
# ### Make a video from the animated gif

# %%
# Requires ffmpeg: sudo apt-get install ffmpeg

convert_to_video(filename=name, overwrite=True)

# %% [markdown]
# ### Compress the generated gif (optional)

# %%
# Requires gifsicle: sudo apt-get install gifsicle

compress_gif(filename=name, scale=0.7)
